# %% [markdown]
# ## 로컬 파일 작성하고 실행하기

# %%
# %%writefile foo.py
print('Hello world')
# Out:
# Writing foo.py

# %%
# %run foo
# Out:
# Hello world

# %% [markdown]
# ## 로컬 & 리모트(URL) 그림파일 보여주기

# %% [markdown]
# 그림파일의 전체 경로를 지정해서 그림보여주는 방법

# %%
from IPython.display import Image, display
i1 ='D:\Dev\ipy_notebooks2\images\open_command_window_here.png'
display(Image(i1))

# %% [markdown]
# 상대경로를 지정하는 방법

# %%
i1 ='.\images\open_command_window_here.png'
display(Image(i1))

# %% [markdown]
# 경로 지정이 잘못되면 그림을 보여줄수 없다

# %%
i1 ='..\images\open_command_window_here.png'
display(Image(i1))

# %% [markdown]
# ## 리모트(URL) 그림을 표시하는 방법
# 원격지 그림 이미지를 표시하는 경우 그림의 URL을 지정해준다.
# 아래처럼 그림위에서 마우스 우클릭하여 그림 URL주소를 복사하면 편리하게 주소를 지정할 수 있다.

# %%
display(Image('.\images\IMG20150731_162640_001.png'))

# %%
display(Image('http://image.kyobobook.co.kr/images/book/large/203/l9788990054203.jpg'))
