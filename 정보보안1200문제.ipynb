# %% [markdown]
# # 정보보안 1200문제

# %% [markdown]
# ##1.정보보호 개요
# ####22문제(1-22)
# 1. 정보보호관리의 개념 7
#
#
# ##2. 암호학
# ####175문제(23-197)
# 2. 암호학 개요     14
# 3. 대칭키 암호     25
# 4. 비대칭키 암호   36
# 5. 해시함수와 응용 44
# 6. 전자서명과 PKI  52
#
#
# ##3. 접근통제
# ####66문제(198-263)
# 7. 접근통제 개요      72
# 8. 사용자 인증        73
# 9. 접근통제 보안 모델 83
# 10. 접근통제 관리      89
# 11. 접근통제 보안위협 및 대응책 90
#
#
# ##4. 시스템 보안
# ####211문제(264-474)
# 12. 운영체제 개요      94
# 13. 운영체제 구성기술 102
# 14. 보안 운영체제     116
# 15. 클라이언트 보안   119
# 16. UNIX 서버 보안    131
# 17. Linux 서버 보안   145
# 18. 윈도우 서버 보안  146
# 19. 서버 보안 관리    154
#
#
# ##5. 네트워크 보안
# ####319문제(475-793)
# 20. 네트워크 개요            164
# 21. TCP/IP                   170
# 22. 라우팅과 라우터 보안     185
# 23. 네트워크 장비의 이해     198
# 24. 무선통신 보안            204
# 25. 네트워크 관리            211
# 26. UNIX/Windows N/W서비스   212
# 27. 네트워크 기반공격의 이해 219
# 28. IDS/IPS                  248
# 29. 침입차단시스템(Firewall) 256
# 30. VPN                      267
# 31. 네트워크 보안동향        274
#
#
# ##6. 어플리케이션 보안
# ####239문제(794-1033)
# 32. FTP 보안                 279
# 33. 이메일 보안              288
# 34. 웹 보안(Web Security)    304
# 35. DNS 보안                 328
# 36. 데이터베이스 보안        331
# 37. 전자상거래 보안          340
# 38. 어플리케이션 보안개발방법 350
# 39. 버퍼오버플로우와 보안위협 352
#
# ##7. 정보보호관리
# ####167문제(1034-1200)
# 40. 정보보호정책 및 조직     365
# 41. 위험 관리                371
# 42. BCP/DRP                  384
# 43. 지적재산권과 침해사고대응 392
# 44. 국제/국가표준 및 인증체계 396
# 45. 정보보호 관련 법규        404
